# %%
"""Imports"""
# %load_ext autoreload
# %autoreload 2

import sys
import os

root = os.path.abspath("..")
if root not in sys.path:
    sys.path.insert(0, root)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.data_loader import load_raw_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
""" Load raw data
"""
df_raw = load_raw_data()
print(f"Raw data loaded: {df_raw.shape}")
# Out:
# Raw data loaded: (5001, 21)

# %%
df_raw.head()
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure_months  \
# 0  CUST-00005    Male               0     Yes        Yes             53
# 1  CUST-00001    Male               0      No        Yes             61
# 2  CUST-00002  Female               0      No         No             68
# 3  CUST-00003    Male               0      No        NaN             62
# 4  CUST-00004    Male               1     Yes         No              1
#
#   phone_service multiple_lines internet_service      online_security  ...  \
# 0           Yes             No               No  No internet service  ...
# 1           Yes             No      Fiber optic                  Yes  ...
# 2           Yes             No               No  No internet service  ...
# 3           Yes             No               No  No internet service  ...
# 4           Yes            Yes              DSL                   No  ...
#
#      device_protection         tech_support         streaming_tv  \
# 0  No internet service  No internet service  No internet service
# 1                   No                   No                   No
# 2  No internet service  No internet service  No internet service
# 3  No internet service  No internet service  No internet service
# 4                   No                   No                   No
#
#       streaming_movies   contract_type paperless_billing    payment_method  \
# 0  No internet service        Two year               Yes  Electronic check
# 1                   No  Month-to-month                No       Credit card
# 2  No internet service  Month-to-month                No       Credit card
# 3  No internet service        Two year               Yes       Credit card
# 4                  Yes  Month-to-month               Yes  Electronic check
#
#   monthly_charges  total_charges churn
# 0           29.29        1553.16    No
# 1           87.04        5303.45    No
# 2           28.63        1944.52    No
# 3           27.85        1736.17    No
# 4           67.92          62.16   Yes
#
# [5 rows x 21 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        5001 non-null   str
#  1   gender             5001 non-null   str
#  2   senior_citizen     5001 non-null   int64
#  3   partner            5001 non-null   str
#  4   dependents         4801 non-null   str
#  5   tenure_months      5001 non-null   int64
#  6   phone_service      5001 non-null   str
#  7   multiple_lines     5001 non-null   str
#  8   internet_service   5001 non-null   str
#  9   online_security    5001 non-null   str
#  10  online_backup      5001 non-null   str
#  11  device_protection  5001 non-null   str
#  12  tech_support       5001 non-null   str
#  13  streaming_tv       5001 non-null   str
#  14  streaming_movies   5001 non-null   str
#  15  contract_type      5001 non-null   str
#  16  paperless_billing  5001 non-null   str
#  17  payment_method     4851 non-null   str
#  18  monthly_charges    5001 non-null   float64
#  19  total_charges      5001 non-null   str
#  20  churn              5001 non-null   str
# dtypes: float64(1), int64(2), str(18)
# memory usage: 1.3 MB

# %%
df_raw.columns
# Out:
# Index(['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents',
#        'tenure_months', 'phone_service', 'multiple_lines', 'internet_service',
#        'online_security', 'online_backup', 'device_protection', 'tech_support',
#        'streaming_tv', 'streaming_movies', 'contract_type',
#        'paperless_billing', 'payment_method', 'monthly_charges',
#        'total_charges', 'churn'],
#       dtype='str')

# %%
""" Convert total charges column from object dtype to float dtype
"""

df = df_raw.copy()

df['total_charges'].isna().sum()
df['total_charges'] = pd.to_numeric(df['total_charges'], errors='coerce')
df['total_charges'].values.dtype
# Out:
# dtype('float64')

# %%
df[['senior_citizen']].value_counts()
# Out:
# senior_citizen
# 0                 4276
# 1                  725
# Name: count, dtype: int64

# %%
df['senior_citizen'] = df['senior_citizen'].map({0: "No", 1: "Yes"})

# %%
df.head()
# Out:
#   customer_id  gender senior_citizen partner dependents  tenure_months  \
# 0  CUST-00005    Male             No     Yes        Yes             53
# 1  CUST-00001    Male             No      No        Yes             61
# 2  CUST-00002  Female             No      No         No             68
# 3  CUST-00003    Male             No      No        NaN             62
# 4  CUST-00004    Male            Yes     Yes         No              1
#
#   phone_service multiple_lines internet_service      online_security  ...  \
# 0           Yes             No               No  No internet service  ...
# 1           Yes             No      Fiber optic                  Yes  ...
# 2           Yes             No               No  No internet service  ...
# 3           Yes             No               No  No internet service  ...
# 4           Yes            Yes              DSL                   No  ...
#
#      device_protection         tech_support         streaming_tv  \
# 0  No internet service  No internet service  No internet service
# 1                   No                   No                   No
# 2  No internet service  No internet service  No internet service
# 3  No internet service  No internet service  No internet service
# 4                   No                   No                   No
#
#       streaming_movies   contract_type paperless_billing    payment_method  \
# 0  No internet service        Two year               Yes  Electronic check
# 1                   No  Month-to-month                No       Credit card
# 2  No internet service  Month-to-month                No       Credit card
# 3  No internet service        Two year               Yes       Credit card
# 4                  Yes  Month-to-month               Yes  Electronic check
#
#   monthly_charges  total_charges  churn
# 0           29.29        1553.16     No
# 1           87.04        5303.45     No
# 2           28.63        1944.52     No
# 3           27.85        1736.17     No
# 4           67.92          62.16    Yes
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        5001 non-null   str
#  1   gender             5001 non-null   str
#  2   senior_citizen     5001 non-null   str
#  3   partner            5001 non-null   str
#  4   dependents         4801 non-null   str
#  5   tenure_months      5001 non-null   int64
#  6   phone_service      5001 non-null   str
#  7   multiple_lines     5001 non-null   str
#  8   internet_service   5001 non-null   str
#  9   online_security    5001 non-null   str
#  10  online_backup      5001 non-null   str
#  11  device_protection  5001 non-null   str
#  12  tech_support       5001 non-null   str
#  13  streaming_tv       5001 non-null   str
#  14  streaming_movies   5001 non-null   str
#  15  contract_type      5001 non-null   str
#  16  paperless_billing  5001 non-null   str
#  17  payment_method     4851 non-null   str
#  18  monthly_charges    5001 non-null   float64
#  19  total_charges      4937 non-null   float64
#  20  churn              5001 non-null   str
# dtypes: float64(2), int64(1), str(18)
# memory usage: 1.3 MB

# %%
""" Impute missing values 
Pass 1: Apply business logic
Pass 2: Statistical approach
        Median, Mean, Mode
"""
mask1 = df['total_charges'].isna()
df[mask1]['tenure_months'].value_counts()
# Out:
# tenure_months
# 0    64
# Name: count, dtype: int64

# %%
df.loc[mask1, 'total_charges'] = 0.0

# %%
df.head()
# Out:
#   customer_id  gender senior_citizen partner dependents  tenure_months  \
# 0  CUST-00005    Male             No     Yes        Yes             53
# 1  CUST-00001    Male             No      No        Yes             61
# 2  CUST-00002  Female             No      No         No             68
# 3  CUST-00003    Male             No      No        NaN             62
# 4  CUST-00004    Male            Yes     Yes         No              1
#
#   phone_service multiple_lines internet_service      online_security  ...  \
# 0           Yes             No               No  No internet service  ...
# 1           Yes             No      Fiber optic                  Yes  ...
# 2           Yes             No               No  No internet service  ...
# 3           Yes             No               No  No internet service  ...
# 4           Yes            Yes              DSL                   No  ...
#
#      device_protection         tech_support         streaming_tv  \
# 0  No internet service  No internet service  No internet service
# 1                   No                   No                   No
# 2  No internet service  No internet service  No internet service
# 3  No internet service  No internet service  No internet service
# 4                   No                   No                   No
#
#       streaming_movies   contract_type paperless_billing    payment_method  \
# 0  No internet service        Two year               Yes  Electronic check
# 1                   No  Month-to-month                No       Credit card
# 2  No internet service  Month-to-month                No       Credit card
# 3  No internet service        Two year               Yes       Credit card
# 4                  Yes  Month-to-month               Yes  Electronic check
#
#   monthly_charges  total_charges  churn
# 0           29.29        1553.16     No
# 1           87.04        5303.45     No
# 2           28.63        1944.52     No
# 3           27.85        1736.17     No
# 4           67.92          62.16    Yes
#
# [5 rows x 21 columns]

# %%
df['total_charges'].isna().sum()
# Out:
# np.int64(0)

# %%
mean = df['total_charges'].mean()

# %%
mask2 = df['total_charges'].isna()
df.loc[mask2, 'total_charges'] = mean

# %%
""" Impute categorical missing columns """

categorical_cols = [
    'dependents', 'payment_method'
]

df['payment_method'].isna().sum()
# Out:
# np.int64(150)

# %%
mode = df['dependents'].mode()[0]

# %%
mask3 = df['dependents'].isna()
df.loc[mask3, 'dependents'] = mode

# %%
df[mask3]
# Out:
#      customer_id  gender senior_citizen partner dependents  tenure_months  \
# 3     CUST-00003    Male             No      No         No             62
# 72    CUST-00072  Female            Yes     Yes         No              2
# 157   CUST-00157    Male             No      No         No             68
# 183   CUST-00183  Female             No     Yes         No             56
# 193   CUST-00193    Male             No     Yes         No             33
# ...          ...     ...            ...     ...        ...            ...
# 4969  CUST-04969    Male             No     Yes         No             48
# 4975  CUST-04975  Female             No      No         No             48
# 4976  CUST-04976  Female             No     Yes         No             53
# 4990  CUST-04990  Female             No     Yes         No             40
# 4995  CUST-04995    Male            Yes      No         No              8
#
#      phone_service    multiple_lines internet_service      online_security  \
# 3              Yes                No               No  No internet service
# 72             Yes               Yes      Fiber optic                   No
# 157            Yes                No      Fiber optic                  Yes
# 183            Yes                No      Fiber optic                   No
# 193             No  No phone service      Fiber optic                  Yes
# ...            ...               ...              ...                  ...
# 4969           Yes               Yes              DSL                   No
# 4975           Yes                No      Fiber optic                  Yes
# 4976           Yes                No               No  No internet service
# 4990           Yes                No      Fiber optic                  Yes
# 4995           Yes               Yes      Fiber optic                   No
#
#       ...    device_protection         tech_support         streaming_tv  \
# 3     ...  No internet service  No internet service  No internet service
# 72    ...                   No                  Yes                  Yes
# 157   ...                   No                   No                  Yes
# 183   ...                   No                  Yes                   No
# 193   ...                   No                   No                  Yes
# ...   ...                  ...                  ...                  ...
# 4969  ...                  Yes                   No                   No
# 4975  ...                   No                  Yes                  Yes
# 4976  ...  No internet service  No internet service  No internet service
# 4990  ...                   No                   No                   No
# 4995  ...                  Yes                   No                   No
#
#          streaming_movies   contract_type paperless_billing    payment_method  \
# 3     No internet service        Two year               Yes       Credit card
# 72                    Yes  Month-to-month               Yes               NaN
# 157                    No        One year               Yes      Mailed check
# 183                    No        One year               Yes      Mailed check
# 193                    No  Month-to-month                No  Electronic check
# ...                   ...             ...               ...               ...
# 4969                  Yes  Month-to-month               Yes      Mailed check
# 4975                   No  Month-to-month               Yes               NaN
# 4976  No internet service  Month-to-month               Yes  Electronic check
# 4990                  Yes  Month-to-month                No      Mailed check
# 4995                   No  Month-to-month                No  Electronic check
#
#      monthly_charges  total_charges  churn
# 3              27.85        1736.17     No
# 72            101.05         206.03     No
# 157            92.34        6282.56     No
# 183            91.65        5136.83     No
# 193            83.32        2747.77     No
# ...              ...            ...    ...
# 4969           70.08        3356.84    Yes
# 4975           98.67        4740.46    Yes
# 4976           28.05        1491.55     No
# 4990           93.50        3749.51     No
# 4995           89.19         711.22     No
#
# [200 rows x 21 columns]

# %%
""" Remove whitespaces from the column values """
df['multiple_lines'].value_counts().keys()
# Out:
# Index(['Yes', 'No', 'No phone service'], dtype='str', name='multiple_lines')

# %%
df['multiple_lines'] = df['multiple_lines'].str.strip()

# %%
var = '  No  '
var.strip()
# Out:
# 'No'

# %%
cols = df.select_dtypes(include="object").columns
cols
# Out:
# C:\Users\Ishrat\AppData\Local\Temp\ipykernel_23532\1161580143.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cols = df.select_dtypes(include="object").columns
# Index(['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents',
#        'phone_service', 'multiple_lines', 'internet_service',
#        'online_security', 'online_backup', 'device_protection', 'tech_support',
#        'streaming_tv', 'streaming_movies', 'contract_type',
#        'paperless_billing', 'payment_method', 'churn'],
#       dtype='str')

# %%
for col in cols:
    df[col] = df[col].str.strip()

# %%
df.columns = (df.columns
 .str.strip()
 .str.lower()
 .str.replace(' ', '_', regex=False)
 .str.replace('-', '_', regex=False))
df.columns
# Out:
# Index(['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents',
#        'tenure_months', 'phone_service', 'multiple_lines', 'internet_service',
#        'online_security', 'online_backup', 'device_protection', 'tech_support',
#        'streaming_tv', 'streaming_movies', 'contract_type',
#        'paperless_billing', 'payment_method', 'monthly_charges',
#        'total_charges', 'churn'],
#       dtype='str')

# %%
""" 
Removal of duplicate rows
"""
mask4 = df.duplicated()
df = df.drop_duplicates(keep='first')

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from src.cleaner import run_full_cleaning_pipeline

df_clean, clean_audit = run_full_cleaning_pipeline(df_raw)

# %%
df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5000 entries, 0 to 5000
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        5000 non-null   str
#  1   gender             5000 non-null   str
#  2   senior_citizen     5000 non-null   str
#  3   partner            5000 non-null   str
#  4   dependents         5000 non-null   str
#  5   tenure_months      5000 non-null   int64
#  6   phone_service      5000 non-null   str
#  7   multiple_lines     5000 non-null   str
#  8   internet_service   5000 non-null   str
#  9   online_security    5000 non-null   str
#  10  online_backup      5000 non-null   str
#  11  device_protection  5000 non-null   str
#  12  tech_support       5000 non-null   str
#  13  streaming_tv       5000 non-null   str
#  14  streaming_movies   5000 non-null   str
#  15  contract_type      5000 non-null   str
#  16  paperless_billing  5000 non-null   str
#  17  payment_method     5000 non-null   str
#  18  monthly_charges    5000 non-null   float64
#  19  total_charges      5000 non-null   float64
#  20  churn              5000 non-null   str
# dtypes: float64(2), int64(1), str(18)
# memory usage: 1.3 MB

# %%
df_clean.head()
# Out:
#   customer_id  gender senior_citizen partner dependents  tenure_months  \
# 0  CUST-00005    Male             No     Yes        Yes             53
# 1  CUST-00001    Male             No      No        Yes             61
# 2  CUST-00002  Female             No      No         No             68
# 3  CUST-00003    Male             No      No         No             62
# 4  CUST-00004    Male            Yes     Yes         No              1
#
#   phone_service multiple_lines internet_service      online_security  ...  \
# 0           Yes             No               No  No internet service  ...
# 1           Yes             No      Fiber optic                  Yes  ...
# 2           Yes             No               No  No internet service  ...
# 3           Yes             No               No  No internet service  ...
# 4           Yes            Yes              DSL                   No  ...
#
#      device_protection         tech_support         streaming_tv  \
# 0  No internet service  No internet service  No internet service
# 1                   No                   No                   No
# 2  No internet service  No internet service  No internet service
# 3  No internet service  No internet service  No internet service
# 4                   No                   No                   No
#
#       streaming_movies   contract_type paperless_billing    payment_method  \
# 0  No internet service        Two year               Yes  Electronic check
# 1                   No  Month-to-month                No       Credit card
# 2  No internet service  Month-to-month                No       Credit card
# 3  No internet service        Two year               Yes       Credit card
# 4                  Yes  Month-to-month               Yes  Electronic check
#
#   monthly_charges  total_charges  churn
# 0           29.29        1553.16     No
# 1           87.04        5303.45     No
# 2           28.63        1944.52     No
# 3           27.85        1736.17     No
# 4           67.92          62.16    Yes
#
# [5 rows x 21 columns]

# %%
tenure_min=0
tenure_max=72
mask1= df_clean['tenure_months']<tenure_min
mask2=df_clean['tenure_months']>tenure_max
mask1.sum(), mask2.sum()
indices = df_clean[mask1 | mask2].index.to_list()
df_clean=df_clean[~(mask1 | mask2)]
df_clean['tenure_months'].value_counts()
# Out:
# tenure_months
# 53    88
# 14    84
# 16    83
# 51    82
# 47    81
#       ..
# 39    58
# 3     56
# 19    55
# 26    51
# 34    50
# Name: count, Length: 73, dtype: int64

# %%
df_clean['monthly_charges'].describe()
# Out:
# count    4995.000000
# mean       74.216460
# std       200.100054
# min        17.510000
# 25%        57.915000
# 50%        73.480000
# 75%        90.780000
# max      9999.000000
# Name: monthly_charges, dtype: float64

# %%
lower_cap=df_clean['monthly_charges'].quantile(1/100)
upper_cap=df_clean['monthly_charges'].quantile(99/100)
print(lower_cap, upper_cap)
below_cap=(df_clean['monthly_charges'] < lower_cap).sum()

above_cap=(df_clean['monthly_charges'] > upper_cap).sum()
print(below_cap, above_cap)
# Out:
# 19.889748 106.22039600000001
# 50 50

# %%
df_clean['monthly_charges']=df_clean['monthly_charges'].clip(lower_cap, upper_cap)

# %%
(df_clean["monthly_charges"] < lower_cap).sum(), (df_clean["monthly_charges"] > upper_cap).sum()
# Out:
# (np.int64(0), np.int64(0))
